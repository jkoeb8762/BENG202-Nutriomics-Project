# %%
from functools import partial
import numpy as np
import scipy
import scipy.optimize
from tqdm import tqdm
import data
violations, vlow, vhigh, deviant_taxonomy_np, nim_np, deviant_taxonomy, nim = data.preprocess()
# Out:
# NORMAL     1414
# OTHER      1271
# DEVIANT     142
# Name: group, dtype: int64
# NIM Amino Acids Shape: (400, 7)
# NIM Amino Acids D Shape: (400, 6)
# NIM Sugars Shape: (400, 56)
# NIM Vitamins Shape: (400, 11)
# nim                                                        Trp     His     Pro  \
# taxonomy
# Faecalibacterium prausnitzii                        0.9377  0.4771  0.0000
# Phocaeicola vulgatus                                0.0000  0.0000  0.1089
# Prevotella copri                                    0.0074  0.0000  0.0077
# Bacteroides uniformis                               0.0000  0.0000  0.0000
# [Eubacterium] rectale                               0.0000  0.0000  0.0000
# ...                                                    ...     ...     ...
# Bacteroides caccae/Bacteroides intestinalis/All...  1.0000  1.0000  1.0000
# Ruthenibacterium lactatiformans/Fournierella ma...  1.0000  0.2000  0.0000
# Stenotrophomonas geniculata/maltophilia/pavanii     0.0000  0.0000  0.0000
# Tepidibaculum saccharolyticum/Ruminococcus albus    0.0000  0.0000  0.0000
# Sellimonas intestinalis/Drancourtella massiliensis  1.0000  0.0000  1.0000
#
#                                                     Leu     Arg  Ile_Val  Tyr  \
# taxonomy
# Faecalibacterium prausnitzii                        0.0  0.0623      0.0  0.0
# Phocaeicola vulgatus                                0.0  0.0000      0.0  0.0
# Prevotella copri                                    0.0  0.0000      0.0  0.0
# Bacteroides uniformis                               0.0  0.0000      0.0  0.0
# [Eubacterium] rectale                               0.0  0.0000      0.0  0.0
# ...                                                 ...     ...      ...  ...
# Bacteroides caccae/Bacteroides intestinalis/All...  1.0  1.0000      1.0  0.0
# Ruthenibacterium lactatiformans/Fournierella ma...  0.0  0.6000      0.0  0.0
# Stenotrophomonas geniculata/maltophilia/pavanii     0.0  0.0000      0.0  0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus    0.0  0.0000      0.0  0.0
# Sellimonas intestinalis/Drancourtella massiliensis  0.0  0.0000      0.0  0.0
#
#                                                      Thr_D  Trp_D   His_D  \
# taxonomy
# Faecalibacterium prausnitzii                        0.0000    0.0  0.0623
# Phocaeicola vulgatus                                0.8911    0.0  0.8911
# Prevotella copri                                    0.0000    0.0  0.0000
# Bacteroides uniformis                               1.0000    1.0  1.0000
# [Eubacterium] rectale                               0.0000    0.0  0.0000
# ...                                                    ...    ...     ...
# Bacteroides caccae/Bacteroides intestinalis/All...  1.0000    0.0  1.0000
# Ruthenibacterium lactatiformans/Fournierella ma...  0.2000    0.0  0.0000
# Stenotrophomonas geniculata/maltophilia/pavanii     1.0000    1.0  1.0000
# Tepidibaculum saccharolyticum/Ruminococcus albus    0.0000    0.0  0.0000
# Sellimonas intestinalis/Drancourtella massiliensis  1.0000    0.0  0.0000
#
#                                                     ...      B2   B3   B5  \
# taxonomy                                            ...
# Faecalibacterium prausnitzii                        ...  0.4771  1.0  1.0
# Phocaeicola vulgatus                                ...  0.0000  0.0  0.0
# Prevotella copri                                    ...  0.0000  0.0  0.0
# Bacteroides uniformis                               ...  0.0000  0.0  0.0
# [Eubacterium] rectale                               ...  0.0000  0.0  0.0
# ...                                                 ...     ...  ...  ...
# Bacteroides caccae/Bacteroides intestinalis/All...  ...  0.0000  1.0  0.0
# Ruthenibacterium lactatiformans/Fournierella ma...  ...  1.0000  0.8  1.0
# Stenotrophomonas geniculata/maltophilia/pavanii     ...  0.0000  0.0  0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus    ...  0.5000  0.0  0.5
# Sellimonas intestinalis/Drancourtella massiliensis  ...  1.0000  0.0  1.0
#
#                                                         B6      B7      B9  \
# taxonomy
# Faecalibacterium prausnitzii                        1.0000  1.0000  0.9377
# Phocaeicola vulgatus                                0.1089  0.1089  0.0000
# Prevotella copri                                    0.0077  1.0000  0.0077
# Bacteroides uniformis                               0.0000  0.0000  0.0000
# [Eubacterium] rectale                               0.0000  1.0000  1.0000
# ...                                                    ...     ...     ...
# Bacteroides caccae/Bacteroides intestinalis/All...  0.0000  1.0000  0.0000
# Ruthenibacterium lactatiformans/Fournierella ma...  1.0000  1.0000  1.0000
# Stenotrophomonas geniculata/maltophilia/pavanii     0.0000  0.0000  0.0000
# Tepidibaculum saccharolyticum/Ruminococcus albus    0.5000  1.0000  1.0000
# Sellimonas intestinalis/Drancourtella massiliensis  1.0000  1.0000  1.0000
#
#                                                        B12       Q  Lipoate  \
# taxonomy
# Faecalibacterium prausnitzii                        0.0623  1.0000   1.0000
# Phocaeicola vulgatus                                0.1089  0.0000   0.1089
# Prevotella copri                                    1.0000  0.3099   1.0000
# Bacteroides uniformis                               0.0000  0.0000   0.0000
# [Eubacterium] rectale                               0.0000  1.0000   1.0000
# ...                                                    ...     ...      ...
# Bacteroides caccae/Bacteroides intestinalis/All...  1.0000  0.0000   1.0000
# Ruthenibacterium lactatiformans/Fournierella ma...  0.0000  1.0000   1.0000
# Stenotrophomonas geniculata/maltophilia/pavanii     1.0000  0.0000   0.0000
# Tepidibaculum saccharolyticum/Ruminococcus albus    1.0000  0.5000   1.0000
# Sellimonas intestinalis/Drancourtella massiliensis  0.0000  1.0000   1.0000
#
#                                                          K
# taxonomy
# Faecalibacterium prausnitzii                        1.0000
# Phocaeicola vulgatus                                0.0000
# Prevotella copri                                    0.0074
# Bacteroides uniformis                               1.0000
# [Eubacterium] rectale                               1.0000
# ...                                                    ...
# Bacteroides caccae/Bacteroides intestinalis/All...  0.0000
# Ruthenibacterium lactatiformans/Fournierella ma...  1.0000
# Stenotrophomonas geniculata/maltophilia/pavanii     1.0000
# Tepidibaculum saccharolyticum/Ruminococcus albus    1.0000
# Sellimonas intestinalis/Drancourtella massiliensis  1.0000
#
# [400 rows x 80 columns]
# taxonomy                                                     ERR2032802  ERR1845748  \
# taxonomy
# Faecalibacterium prausnitzii                               4.4        12.3
# Phocaeicola vulgatus                                      23.4        11.0
# Prevotella copri                                           0.1         0.0
# Bacteroides uniformis                                      4.1         5.5
# [Eubacterium] rectale                                      4.2        22.7
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR2092355  ERR1845937  \
# taxonomy
# Faecalibacterium prausnitzii                               2.0         3.1
# Phocaeicola vulgatus                                      19.4        10.9
# Prevotella copri                                           0.1        32.4
# Bacteroides uniformis                                      4.0         0.0
# [Eubacterium] rectale                                      1.1         0.0
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1249738  ERR1090583  \
# taxonomy
# Faecalibacterium prausnitzii                              11.6         5.8
# Phocaeicola vulgatus                                       4.4         5.7
# Prevotella copri                                          48.0        71.8
# Bacteroides uniformis                                      0.2         0.0
# [Eubacterium] rectale                                      0.3         0.0
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1250049  ERR1459183  \
# taxonomy
# Faecalibacterium prausnitzii                               2.5         9.8
# Phocaeicola vulgatus                                       1.7        16.8
# Prevotella copri                                          63.9         0.0
# Bacteroides uniformis                                      0.7         4.8
# [Eubacterium] rectale                                      0.2         6.6
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1075840  ERR1458892  \
# taxonomy
# Faecalibacterium prausnitzii                               6.8         3.3
# Phocaeicola vulgatus                                       5.2        16.1
# Prevotella copri                                           0.0         0.0
# Bacteroides uniformis                                      7.2         1.1
# [Eubacterium] rectale                                      2.9         0.0
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ...  ERR2057080  \
# taxonomy                                            ...
# Faecalibacterium prausnitzii                        ...         1.8
# Phocaeicola vulgatus                                ...         0.5
# Prevotella copri                                    ...         0.0
# Bacteroides uniformis                               ...         0.5
# [Eubacterium] rectale                               ...         0.0
# ...                                                 ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...  ...         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...  ...         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii     ...         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus    ...         0.0
# Sellimonas intestinalis/Drancourtella massiliensis  ...         0.0
#
#                                                     ERR1678465  ERR1074540  \
# taxonomy
# Faecalibacterium prausnitzii                              10.3         2.7
# Phocaeicola vulgatus                                       0.3         0.1
# Prevotella copri                                           0.9         7.6
# Bacteroides uniformis                                      0.3         0.0
# [Eubacterium] rectale                                      0.2         0.1
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1077998  ERR2033465  \
# taxonomy
# Faecalibacterium prausnitzii                               0.9         2.6
# Phocaeicola vulgatus                                       0.0         8.5
# Prevotella copri                                           0.1         0.0
# Bacteroides uniformis                                      2.3         2.0
# [Eubacterium] rectale                                      0.0         0.6
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1389801  ERR1845840  \
# taxonomy
# Faecalibacterium prausnitzii                               0.7         3.6
# Phocaeicola vulgatus                                       5.3         0.5
# Prevotella copri                                           0.0         0.7
# Bacteroides uniformis                                      0.2         1.0
# [Eubacterium] rectale                                      0.1         0.6
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1842195  ERR1075183  \
# taxonomy
# Faecalibacterium prausnitzii                               2.9         0.2
# Phocaeicola vulgatus                                       0.1         0.1
# Prevotella copri                                           0.0         0.2
# Bacteroides uniformis                                      0.0         0.0
# [Eubacterium] rectale                                      0.0         0.0
# ...                                                        ...         ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0         0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0         0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0         0.0
#
#                                                     ERR1077294
# taxonomy
# Faecalibacterium prausnitzii                               4.7
# Phocaeicola vulgatus                                       0.0
# Prevotella copri                                           0.5
# Bacteroides uniformis                                      0.1
# [Eubacterium] rectale                                      0.0
# ...                                                        ...
# Bacteroides caccae/Bacteroides intestinalis/All...         0.0
# Ruthenibacterium lactatiformans/Fournierella ma...         0.0
# Stenotrophomonas geniculata/maltophilia/pavanii            0.0
# Tepidibaculum saccharolyticum/Ruminococcus albus           0.0
# Sellimonas intestinalis/Drancourtella massiliensis         0.0
#
# [400 rows x 2827 columns]
# Faecalibacterium prausnitzii
# v_low : 5.4
# v_high: 23.3
# Normal Taxonomy
# [0 1 0 ... 4 3 1]
# Mean Violoations: 1.7411598302687412
#
# Deviant Taxonomy
# [13 16  5  8 11  4  7  9 12  9  7 12  8 14  9 15  7 16 15  5  6  9  9  7
#  18  4  7 14  6  7 18  7 11  7 16  3 14 10 16  9 10  6 10 10  6 14  9 14
#   8 11  8  8 17 10 17 18 18 20 18 19 11 14 18 19 17 17 17 19 18 18 19  9
#  19 18 17 20 17 18 19 20 18 16 22 18 17 20 17 17 21 17 11 13  2  9  6  7
#   9 17  7  5 10 19  9 10  9  6  9  8  9 11  9  9  9 11  5 12  7  8 10 15
#  10  9  9 18  7  7  6 13 10 11 12  7 10  8 13  5  7 10 11  7 12  9]
# Mean Violoations: 11.76056338028169

# %%
# extra defs
nvars = nim_np.shape[1]

# %%
def convert_problem_into_lp(u, v_low, v_high, nim, sparsity_penalty, constraint_violation_penalty):
    # min violations of v_low <= nim * x + u <= v_high, x should be sparse
    n, m = nim.shape
    assert u.shape[0] == v_low.shape[0] == v_high.shape[0] == n
    constraint_coef = []
    bias_v = []
    for i in range(n):
        # nim * x - 1 * y <= v_high - u
        constraint_coef.append(nim[i].tolist() + [-1 if j == i else 0 for j in range(2 * n)])
        bias_v.append(v_high[i] - u[i])
    for i in range(n):
        # -nim * x - 1 * y <= -v_low + u
        constraint_coef.append((-nim[i]).tolist() + [-1 if j - n == i else 0 for j in range(2 * n)])
        bias_v.append(-v_low[i] + u[i])
    c = []
    for i in range(m):
        c.append(sparsity_penalty)
    for i in range(2 * n):
        c.append(constraint_violation_penalty)
    return np.array(constraint_coef), np.array(bias_v), np.array(c)

nvars = nim_np.shape[1]

def grid_search(k_sparse, sparsity_low, sparsity_high, sparsity_delta, violation_low, violation_high, violation_delta, lp_fn, eval_fn):
    best_answer = (1e9, )
    sparsity_chunks = int((sparsity_high - sparsity_low) / sparsity_delta + 0.5)
    violation_chunks = int((violation_high - violation_low) / violation_delta + 0.5)
    for sparsity_i in range(sparsity_chunks):
        sparsity_p = sparsity_low + sparsity_i * sparsity_delta
        for violation_i in range(violation_chunks):
            violation_p = violation_low + violation_i * violation_delta
            r = lp_fn(sparsity_penalty=sparsity_p, constraint_violation_penalty=violation_p)
            if r.success:
                non_zero_elements = len(r.x[: nvars].nonzero()[0])
                if non_zero_elements <= k_sparse:
                    best_answer = min(best_answer, (eval_fn(r.x[: nvars]), sparsity_p, violation_p, r.x[: nvars]))
    return best_answer

def binary_search(k_sparse, sparsity_low, sparsity_high, sparsity_delta, violation_low, violation_high, violation_delta, lp_fn, eval_fn):
    best_answer = (1e9, )
    # sparsity_p higher -> valid x
    # violation_p higher -> better sol
    # highest violation such that sparsity is satisfied
    while violation_low < violation_high - violation_delta:
        violation_p = (violation_low + violation_high) / 2
        s_low = sparsity_low
        s_high = sparsity_high
        found = False
        while s_low < s_high - sparsity_delta:
            sparsity_p = (s_low + s_high) / 2
            r = lp_fn(sparsity_penalty=sparsity_p, constraint_violation_penalty=violation_p)
            if r.success and len(r.x[: nvars].nonzero()[0]) <= k_sparse:
                best_answer = min(best_answer, (eval_fn(r.x[: nvars]), sparsity_p, violation_p, r.x[: nvars]))
                s_high = sparsity_p
                found = True
            else:
                s_low = sparsity_p
        if found:
            violation_low = violation_p
        else:
            violation_high = violation_p
    return best_answer

def solve_problem_with_lp(u, v_low, v_high, nim, sparsity_penalty, constraint_violation_penalty):
    A, b, c = convert_problem_into_lp(u, v_low, v_high, nim, sparsity_penalty, constraint_violation_penalty)
    return scipy.optimize.linprog(c, A_ub=A, b_ub=b, method='highs')

# %%
def solve_problem_with_random(nvars, k_sparse):
    indices = np.random.choice(nvars, k_sparse)
    values = np.random.uniform(0, 1, k_sparse)
    x = np.zeros(nvars)
    x[indices] = values
    return x

def random_trial(k_sparse, max_trials, sample_fn, eval_fn):
    best_answer = (1e9, )
    for trial in range(max_trials):
        x = sample_fn(k_sparse=k_sparse)
        for alpha in range(20):
            x_p = x * alpha / 10
            best_answer = min(best_answer, (eval_fn(x_p), alpha, trial, x_p))
    return best_answer

# %%
k_sparse = 10
violations_before = []
violations_after = []
def eval_fn(x):
    return violations((nim_np @ x[:, np.newaxis]).squeeze(1) + deviant_sample)[0]
for deviant_sample in tqdm(deviant_taxonomy_np.T):
    # linear_programming, can use either binary_search or grid search
    lp_fn = partial(solve_problem_with_lp, u=deviant_sample, v_low=vlow, v_high=vhigh, nim=nim_np)
    best_answer = binary_search(k_sparse, 0, 1, 0.2, 0, 1, 0.2, lp_fn, eval_fn)

    # random search
#     sample_fn = partial(solve_problem_with_random, nvars=nvars)
#     best_answer = random_trial(k_sparse, 1000, sample_fn, eval_fn)

    violations_before.append(violations(deviant_sample)[0])
    violations_after.append(best_answer[0])
print(np.mean(violations_before), np.mean(violations_after))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 142/142 [11:40<00:00,  4.94s/it]
# 11.76056338028169 3.8028169014084505
